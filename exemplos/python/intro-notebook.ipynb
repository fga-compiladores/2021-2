# %%
x = 42
y = 10

# %%
print(x + y)
# Out:
# 52

# %%
from matplotlib import pyplot as plt
from math import sin, cos, exp

Xs = [i * 0.1 for i in range(101)]
Ys = [exp(- 0.5 * x) * cos(2 * x) for x in Xs]

plt.plot(Xs, Ys)
plt.show()
